# %% [markdown]
# # Generate the data

# %%
import numpy as np
import tensorflow as tf
# %matplotlib notebook

# %%
n = 50
x = np.arange(0,n,1,dtype=np.float64)

m = np.random.uniform(0.3,0.5,(n,))
b = np.random.uniform(5,10,(n,))
y = m * x + b

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### Neural network

# %%
model = tf.keras.models.Sequential([
          tf.keras.layers.Dense(units = 1, input_shape = (1,))
])
print(model.summary())

model.compile(optimizer = keras.optimizers.SGD(learning_rate=0.0009),
              loss = 'mean_squared_error')

history = model.fit(x = x,
                    y = y,
                    epochs = 1500)
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_26 (Dense)             (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1500
# 2/2 [==============================] - 0s 0s/step - loss: 1701.9626
# Epoch 2/1500
# 2/2 [==============================] - 0s 0s/step - loss: 70.6283
# Epoch 3/1500
# 2/2 [==============================] - 0s 0s/step - loss: 24.8103
# Epoch 4/1500
# 2/2 [==============================] - 0s 0s/step - loss: 22.8427
# Epoch 5/1500
# 2/2 [==============================] - 0s 0s/step - loss: 24.0376
# Epoch 6/1500
# 2/2 [==============================] - 0s 0s/step - loss: 23.5814
# Epoch 7/1500
# 2/2 [==============================] - 0s 3ms/step - loss: 22.4198
# Epoch 8/1500
# ...

# %%
plt.scatter(x, y)
plt.plot(model.predict(x), color = 'red')
plt.title("Plot for predicted and actual values")
plt.show()

plt.plot(history.history['loss'])
plt.title('Loss value of model')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="481.6">
